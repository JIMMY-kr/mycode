# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.25, random_state=3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
#의사결정나무 모형
model = DecisionTreeClassifier(random_state=2, max_depth=3, criterion='entropy')
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=2)

# %%
print('학습용:', model.score(X_train, y_train))
print('검증용:', model.score(X_test, y_test))
# Out:
# 학습용: 0.9066666666666666
# 검증용: 0.92

# %%
from sklearn.tree import export_graphviz
import pydotplus
import graphviz
from IPython.display import Image
import os

#환경변수 선언
os.environ['PATH'] += os.pathsep + 'c:/Program Files/Graphviz/bin/'
dot_data = export_graphviz(model, out_file=None,
feature_names=[0,1], class_names=['0', '1'],
filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

#의사결정 나무의 하나 하나를 노드라고 일컬음

# %%
import matplotlib.pyplot as plt
import mglearn
plt.figure(figsize=(9,6))
plt.title('Tree')

mglearn.plots.plot_2d_separator(model, X, fill=True, alpha=0.4)
mglearn.discrete_scatter(X[:,0], X[:,1], y)
# Out:
# [<matplotlib.lines.Line2D at 0x2a5b20b7be0>,
#  <matplotlib.lines.Line2D at 0x2a5b20b7f70>]
