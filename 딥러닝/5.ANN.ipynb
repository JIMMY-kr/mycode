# %%
#인공신경망(ANN)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

x = np.array([0,1,2,3,4])
y = x*2+1
print('x:', x)
print('y:', y)

model = Sequential()
model.add(Dense(1, input_shape=(1,))) #input_shape 입력변수 1개
#sgd 확률적경사하강법
model.compile(optimizer='sgd', loss='mse')

#모델 함수
model.fit(x[:2].reshape(-1,1), y[:2].reshape(-1,1), epochs=500, verbose=1)
# Out:
# x: [0 1 2 3 4]
# y: [1 3 5 7 9]
# Epoch 1/500
# 1/1 [==============================] - 1s 744ms/step - loss: 2.4286
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3038
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1855
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0733
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9669
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8659
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7702
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6794
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5933
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5117
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4343
# Epoch 12/500
# ...

# %%
# 성능평가
mse = model.evaluate(x[2:], y[2:])
print(mse)
print('실제값:', y[2:])
print('예측값:', model.predict(x[2:]).flatten())
# Out:
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0087
# 0.00865344051271677
# 실제값: [5 7 9]
# 예측값: [4.948944 6.912002 8.87506 ]
